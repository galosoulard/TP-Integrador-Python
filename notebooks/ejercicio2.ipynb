# %%
import sys
import os

#Agregamos la carpeta principal del proyecto a sys.path para poder acceder a todas las carpetas
sys.path.append(os.path.abspath('..'))

from modules import data_reader
from pathlib import Path

# %% [markdown]
# ### EJERCICIO 2.A

# %%
path_iadiza = Path('..') / 'raw_datasets' / 'Colección Ornitológica del IADIZA-CCT CONICET Mendoza IADIZA-COI' / 'occurrence.txt'
delimiter_iadiza = '\t'

#Imprimimos las 10 primeras filas del data set IADIZA
data_reader.print_first_rows(path_iadiza, delimiter_iadiza)

# %%
path_inaturalist = Path('..') / 'raw_datasets' / 'inaturalist-filtered' / 'observations.csv'
delimiter_inaturalist = ','

#Imprimimos las 10 primeras filas del data set inaturalist
data_reader.print_first_rows(path_inaturalist, delimiter_inaturalist)

# %%
path_xeno = Path('..') / 'raw_datasets' / 'xeno-canto-bird-sounds-filtered' / 'Occurrence.txt'
delimiter_xeno = ','

#Imprimimos las 10 primeras filas del data set xeno
data_reader.print_first_rows(path_xeno, delimiter_xeno)

# %% [markdown]
# ### EJERCICIO 2.B

# %%
#Guardamos una lista con el header del data set iadiza
columns_iadiza = data_reader.get_column_names(path_iadiza, delimiter_iadiza)
print(columns_iadiza)

# %%
#Guardamos una lista con el header del data set inaturalist
columns_inaturalist = data_reader.get_column_names(path_inaturalist, delimiter_inaturalist)
print(columns_inaturalist)

# %%
#Guardamos una lista con el header del data set xeno
columns_xeno = data_reader.get_column_names(path_xeno, delimiter_xeno)
print(columns_xeno)

# %% [markdown]
# ### EJERCICIO 2.C

# %%
column_indices_iadiza = data_reader.get_column_indices(path_iadiza, delimiter_iadiza)
print(column_indices_iadiza)

# %%
column_indices_inaturalist = data_reader.get_column_indices(path_inaturalist, delimiter_inaturalist)
print(column_indices_inaturalist)

# %%
column_indices_xeno = data_reader.get_column_indices(path_xeno, delimiter_xeno)
print(column_indices_xeno)
